# %%
import pandas as pd

a = pd.read_csv('sentiment-bias-annotations_aashka_132-231.csv')
b = pd.read_csv('sentiment-bias-annotations_anna_66-165.csv')
c = pd.read_csv('sentiment-bias-annotations_fatma_33-132.csv')

df = pd.merge(a,b,on=['annotation_index', 'index', 'sentence', 'label', 'gender'],how='outer')
df = pd.merge(df,c,on=['annotation_index', 'index', 'sentence', 'label', 'gender'],how='outer')

# %%
df
# Out:
#      annotation_index  index  \
# 0                 132   4157
# 1                 133   5936
# 2                 134   3104
# 3                 135    185
# 4                 136    339
# ..                ...    ...
# 194                61    158
# 195                62   2113
# 196                63   3588
# 197                64   3620
# 198                65   8182
#
#                                               sentence  label gender  aashka  \
# 0    is significantly less charming than listening ...   0.08   masc     1.0
# 1    For all the time we spend with these people , ...   0.39   neut     NaN
# 2    One of the pleasures in Walter 's documentary ...   0.56   masc     NaN
# 3    Maud and Roland 's search for an unknowable pa...   0.83   masc     NaN
# 4    It made me want to get made-up and go see this...   0.72   femm     NaN
# ..                                                 ...    ...    ...     ...
# ...
